# %%
import pandas as pd
import numpy as np
import requests
from bs4 import BeautifulSoup
import re
import urllib
from time import sleep
import json

# %%
url = 'https://www.espn.com/nba/teams'
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/114.0.0.0 Safari/537.36'}
r = requests.get(url, headers=headers)

teams_source = r.text

teams = dict(re.findall(r"www\.espn\.com/nba/team/_/name/(\w+)/(.+?)\",", teams_source))

roster_urls = []

for key in teams.keys():
    roster_urls.append("www.espn.com/nba/team/_/name/" + key + '/' + teams[key])
    teams[key] = str(teams[key])

dict(zip(teams.values(),roster_urls))
# Out:
# {'boston-celtics': 'www.espn.com/nba/team/_/name/bos/boston-celtics',
#  'brooklyn-nets': 'www.espn.com/nba/team/_/name/bkn/brooklyn-nets',
#  'new-york-knicks': 'www.espn.com/nba/team/_/name/ny/new-york-knicks',
#  'philadelphia-76ers': 'www.espn.com/nba/team/_/name/phi/philadelphia-76ers',
#  'toronto-raptors': 'www.espn.com/nba/team/_/name/tor/toronto-raptors',
#  'chicago-bulls': 'www.espn.com/nba/team/_/name/chi/chicago-bulls',
#  'cleveland-cavaliers': 'www.espn.com/nba/team/_/name/cle/cleveland-cavaliers',
#  'detroit-pistons': 'www.espn.com/nba/team/_/name/det/detroit-pistons',
#  'indiana-pacers': 'www.espn.com/nba/team/_/name/ind/indiana-pacers',
#  'milwaukee-bucks': 'www.espn.com/nba/team/_/name/mil/milwaukee-bucks',
#  'atlanta-hawks': 'www.espn.com/nba/team/_/name/atl/atlanta-hawks',
#  'charlotte-hornets': 'www.espn.com/nba/team/_/name/cha/charlotte-hornets',
#  'miami-heat': 'www.espn.com/nba/team/_/name/mia/miami-heat',
# ...

# %%
# Pobranie strony
url = "https://www.espn.com/nba/team/roster/_/name/gs/golden-state-warriors"
response = urllib.request.urlopen(url)
page_source = response.read().decode('utf-8')

# Dopasowanie obiektów JSON zawodników
data_regex = r'\{"shortName":.*?"experience":\d+,"college":"[^"]*"\}'  # Poprawny zakres JSON
json_data_matches = re.findall(data_regex, page_source)

# Parsowanie danych JSON
players = []
for match in json_data_matches:
    try:
        players.append(json.loads(match))  # Walidacja i parsowanie JSON
    except json.JSONDecodeError as e:
        print(f"Error decoding JSON: {e}")
        continue  # Pomijamy niepoprawne dane


players
# Out:
# Error decoding JSON: Extra data: line 1 column 455 (char 454)
# Error decoding JSON: Extra data: line 1 column 435 (char 434)
# [{'shortName': 'K. Anderson',
#   'name': 'Kyle Anderson',
#   'href': 'https://www.espn.com/nba/player/_/id/2993874/kyle-anderson',
#   'uid': 's:40~l:46~a:2993874',
#   'guid': '0b5e3fdc-796d-c463-655c-9c8f6622bcd0',
#   'id': '2993874',
#   'height': '6\' 9"',
#   'weight': '230 lbs',
#   'age': 31,
#   'position': 'SF',
#   'hand': 'L',
#   'jersey': '1',
#   'salary': '$8,780,488',
#   'birthDate': '09/20/93',
#   'headshot': 'https://a.espncdn.com/i/headshots/nba/players/full/2993874.png',
#   'lastName': 'Kyle Anderson',
#   'experience': 10,
#   'college': 'UCLA'},
#  {'shortName': 'R. Beekman',
#   'name': 'Reece Beekman',
#   'href': 'https://www.espn.com/nba/player/_/id/4432187/reece-beekman',
#   'uid': 's:40~l:46~a:4432187',
#   'guid': 'a580564e-7e01-3273-ba10-6a1bbe6a30c1',
#   'id': '4432187',
#   'height': '6\' 3"',
#   'weight': '190 lbs',
# ...
